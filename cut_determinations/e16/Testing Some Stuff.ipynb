# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import math
import pandas as pd
#import uproot
import uproot3
from scipy import optimize as op
import scipy.integrate as integrate

# %%
x = [0,1,2,3,4,5,6,7]
y = [i*i - 4*i + 2 for i in range(8)]
x0 = [0 for i in range(8)]
yerr = [[np.sqrt(np.abs(y[i])) for i in range(8)],[-np.sqrt(np.abs(y[i])) for i in range(8)]]

# %%
plt.scatter(x,y,label="cross section")
plt.bar(x,yerr[0],alpha=0.2,color='g',label='systematic error',width=1.0)
plt.bar(x,yerr[1],alpha=0.2,color='g',width=1.0)
plt.legend()
plt.show()
